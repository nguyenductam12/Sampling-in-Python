# %%
import pandas as pd
import pyarrow.feather as pq
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# <h1>Sampling in Python</h1>

# %% [markdown]
# <img src="https://hotcubator.com.au/wp-content/uploads/2020/07/Copy-of-Social-Business-1.png">

# %%
coffee_ratings_full = pd.read_feather('data/coffee_ratings_full.feather')
coffee_ratings_full.sample(10)
# Out:
#       total_cup_points  species                             owner  \
# 756              82.17  Arabica                   ipanema coffees
# 475              83.17  Arabica                          nucoffee
# 866              81.75  Arabica     armando luis pohlenz martinez
# 646              82.58  Arabica    exportadora de cafe condor s.a
# 214              84.17  Arabica         juan luis alvarado romero
# 544              82.92  Arabica                kawacom uganda ltd
# 1197             79.08  Arabica                racafe & cia s.c.a
# 58               85.83  Arabica         juan luis alvarado romero
# 629              82.67  Arabica  kona pacific farmers cooperative
# 36               86.25  Arabica  kona pacific farmers cooperative
#
#            country_of_origin                    farm_name lot_number  \
# 756                   Brazil           fazenda capoeirnha    007/16C
# 475                   Brazil                 olhos d'agua       None
# ...

# %%
attrition = pd.read_feather("data/attrition.feather")
attrition.sample(10)
# Out:
#       Age  Attrition     BusinessTravel  DailyRate            Department  \
# 173    32        0.0         Non-Travel        976                 Sales
# 45     27        0.0      Travel_Rarely        618  Research_Development
# 858    32        0.0      Travel_Rarely        495  Research_Development
# 522    41        1.0      Travel_Rarely       1102                 Sales
# 107    35        0.0  Travel_Frequently        636  Research_Development
# 1257   38        0.0  Travel_Frequently       1394  Research_Development
# 247    26        1.0      Travel_Rarely       1449  Research_Development
# 592    33        0.0  Travel_Frequently       1111                 Sales
# 129    21        1.0  Travel_Frequently        756                 Sales
# 131    31        0.0      Travel_Rarely        408  Research_Development
#
#       DistanceFromHome      Education    EducationField  \
# 173                 26         Master         Marketing
# ...

# %%
spotify_2000_2020 = pd.read_feather("data/spotify_2000_2020.feather")
spotify_2000_2020.sample(10)
# Out:
#        acousticness                  artists  danceability  duration_ms  \
# 20508      0.281000     ['Futuristic', 'NF']         0.754     249168.0
# 24039      0.057800          ['Arcade Fire']         0.616     315200.0
# 23018      0.000548         ['Gary Glitter']         0.752     180600.0
# 14068      0.055600               ['Halsey']         0.500     165213.0
# 33019      0.371000          ['Niall Horan']         0.443     223044.0
# 40878      0.000506        ['Nipsey Hussle']         0.678     209427.0
# 23341      0.628000  ['Jesús Adrián Romero']         0.490     327653.0
# 35142      0.282000            ['Sam Smith']         0.535     221596.0
# 5570       0.825000            ['Daft Punk']         0.712     322147.0
# 3177       0.793000           ['Cody Jinks']         0.559     188613.0
#
#        duration_minutes  energy  explicit                      id  \
# 20508          4.152800   0.823       1.0  7whWjytFNIYch6MAnIWZTS
# ...
