# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# <h1 style = "color:'blue'">Sampling in Python</h1>

# %% [markdown]
# <img src="https://hotcubator.com.au/wp-content/uploads/2020/07/Copy-of-Social-Business-1.png">

# %%
coffee_ratings_full = pd.read_feather('data/coffee_ratings_full.feather')
coffee_ratings_full.sample(10)
# Out:
#       total_cup_points  species  \
# 264              83.92  Arabica
# 409              83.33  Arabica
# 633              82.58  Arabica
# 624              82.67  Arabica
# 101              85.00  Arabica
# 1283             74.75  Arabica
# 650              82.58  Arabica
# 41               86.17  Arabica
# 10               88.08  Arabica
# 389              83.42  Arabica
#
#                                                 owner country_of_origin  \
# 264                                          almacafe          Colombia
# 409                                   carcafe ltda ci          Colombia
# 633                         juan luis alvarado romero         Guatemala
# 624                         juan luis alvarado romero         Guatemala
# 101                  rashid moledina & co. (msa) ltd.             Kenya
# 1283                        juan luis alvarado romero         Guatemala
# 650   organizaciones de productores de cafe colimense            Mexico
# ...

# %%
attrition = pd.read_feather("data/attrition.feather")
attrition.sample(10)
# Out:
#       Age  Attrition     BusinessTravel  DailyRate            Department  \
# 1168   35        0.0      Travel_Rarely       1017  Research_Development
# 524    32        0.0  Travel_Frequently       1005  Research_Development
# 1011   37        0.0  Travel_Frequently        319                 Sales
# 176    27        0.0      Travel_Rarely       1220  Research_Development
# 1312   50        0.0      Travel_Rarely        939  Research_Development
# 1464   55        0.0      Travel_Rarely        452  Research_Development
# 1280   42        0.0      Travel_Rarely        265                 Sales
# 166    24        0.0      Travel_Rarely       1353                 Sales
# 511    40        0.0      Travel_Rarely        616  Research_Development
# 122    21        0.0      Travel_Rarely        501                 Sales
#
#       DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# 1168                 6         Master  Life_Sciences                  Medium
# ...

# %%
spotify_2000_2020 = pd.read_feather("data/spotify_2000_2020.feather")
spotify_2000_2020.sample(10)
# Out:
#        acousticness                          artists  danceability  \
# 26885       0.12400                ['gianni & kyle']         0.918
# 8821        0.15300               ['Aniceto Molina']         0.835
# 29560       0.68900     ['Cardenales De Nuevo León']         0.652
# 14529       0.18700                           ['KB']         0.674
# 31863       0.00928  ['Dick Dale and his Del-Tones']         0.295
# 31906       0.18500              ['Jennifer Hudson']         0.464
# 1982        0.03730                 ['Old Dominion']         0.424
# 9668        0.44100                 ['Prince Royce']         0.807
# 39873       0.01910                ['Todd Rundgren']         0.677
# 30686       0.19400        ['Moguai', 'Cheat Codes']         0.611
#
#        duration_ms  duration_minutes  energy  explicit  \
# 26885     181710.0          3.028500   0.449       1.0
# 8821      207800.0          3.463333   0.651       0.0
# 29560     161893.0          2.698217   0.402       0.0
# ...

# %% [markdown]
# Compare mean() n_sample = 1000 with all data rows

# %%
n_sample = attrition['Age'].sample(n = 1000)
print(f'(n_sample = 1000) => {n_sample.mean()} \nattrition["Age"].mean() = {attrition["Age"].mean()}')
print('=> n_sample.mean() ~ attrition["Age"].mean()')
# Out:
# (n_sample = 1000) => 36.74
# attrition["Age"].mean() = 36.923809523809524
# => n_sample.mean() ~ attrition["Age"].mean()

# %% [markdown]
# <b style = "color:'red'">Simple sampling and calculating with NumPy</b>

# %% [markdown]
# >You can also use `numpy` to calculate parameters or statistics from a list or `pandas` Series.
#
# >You'll be turning it up to eleven and looking at the `loudness` property of each song.
#
# >`spotify_population` is available and `numpy` is loaded as `np`.

# %%
spotify_2000_2020.columns
# Out:
# Index(['acousticness', 'artists', 'danceability', 'duration_ms',
#        'duration_minutes', 'energy', 'explicit', 'id', 'instrumentalness',
#        'key', 'liveness', 'loudness', 'mode', 'name', 'popularity',
#        'release_date', 'speechiness', 'tempo', 'valence', 'year'],
#       dtype='object')

# %%
# Create a pandas Series from the loudness column of spotify_population
loudness_pop = spotify_2000_2020['loudness']

# Sample 100 values of loudness_pop
loudness_samp = loudness_pop.sample(n = 100)

loudness_samp
# Out:
# 27859    -6.716
# 28568    -5.164
# 39460    -3.359
# 17300    -9.313
# 40541    -4.637
#           ...
# 22308    -5.948
# 25187   -13.337
# 38885    -8.147
# 5429     -4.454
# 39249    -2.182
# Name: loudness, Length: 100, dtype: float64

# %% [markdown]
# <i>Simple sampling and calculating with NumPy</i>
# >You can also use numpy to calculate parameters or statistics from a list or pandas Series.
#
# >You'll be turning it up to eleven and looking at the loudness property of each song.
#
# >spotify_population is available and numpy is loaded as np.

# %%
# Create a pandas Series from the loudness column of spotify_population
loudness_pop = spotify_2000_2020['loudness']

# Sample 100 values of loudness_pop
loudness_samp = loudness_pop.sample(n=100)

# Calculate the mean of loudness_pop
mean_loudness_pop = np.mean(loudness_pop)

# Calculate the mean of loudness_samp
mean_loudness_samp = np.mean(loudness_samp)

print(mean_loudness_pop)
print(mean_loudness_samp)
# Out:
# -7.366856851353947
# -7.281909999999999

# %% [markdown]
# <h3>Convenience sampling</h3>

# %% [markdown]
# <img src="file:///Users/nguyentam/Desktop/Screenshot%202023-11-09%20at%2023.18.06.png">

# %%
coffee_ratings_full.columns
# Out:
# Index(['total_cup_points', 'species', 'owner', 'country_of_origin',
#        'farm_name', 'lot_number', 'mill', 'ico_number', 'company', 'altitude',
#        'region', 'producer', 'number_of_bags', 'bag_weight',
#        'in_country_partner', 'harvest_year', 'grading_date', 'owner_1',
#        'variety', 'processing_method', 'aroma', 'flavor', 'aftertaste',
#        'acidity', 'body', 'balance', 'uniformity', 'clean_cup', 'sweetness',
#        'cupper_points', 'moisture', 'category_one_defects', 'quakers', 'color',
#        'category_two_defects', 'expiration', 'certification_body',
#        'certification_address', 'certification_contact', 'unit_of_measurement',
#        'altitude_low_meters', 'altitude_high_meters', 'altitude_mean_meters'],
#       dtype='object')

# %%
np.random.seed(123)
n_sample_coffee = coffee_ratings_full.sample(n = 1000)
sns.histplot(data= n_sample_coffee, x = 'total_cup_points', color="red", bins=np.arange(59, 93, 2))
sns.histplot(data=coffee_ratings_full, x = 'total_cup_points', alpha = 0.5, bins=np.arange(59, 93, 2))
# Out:
# <Axes: xlabel='total_cup_points', ylabel='Count'>

# %% [markdown]
# <h4>Are findings from the sample generalizable?</h4>
#
# >You just saw how convenience sampling—collecting data using the easiest method—can result in samples that aren't representative of the population. Equivalently, this means findings from the sample are not generalizable to the population. Visualizing the distributions of the population and the sample can help determine whether the sample is representative of the population.
#
# >The Spotify dataset contains an `acousticness` column, which is a confidence measure from zero to one of whether the track was made with instruments that aren't plugged in. You'll compare the `acousticness` distribution of the total population of songs with a sample of those songs.
#
# >`spotify_population` and `spotify_mysterious_sample` are available; `pandas as pd`, `matplotlib.pyplot as plt`, and `numpy as np` are loaded.

# %%
spotify_2000_2020.head(2)
# Out:
#    acousticness          artists  danceability  duration_ms  duration_minutes  \
# 0         0.972  ['David Bauer']         0.567     313293.0           5.22155
# 1         0.321   ['Etta James']         0.821     360240.0           6.00400
#
#    energy  explicit                      id  instrumentalness   key  liveness  \
# 0   0.227       0.0  0w0D8H1ubRerCXHWYJkinO          0.601000  10.0     0.110
# 1   0.418       0.0  4JVeqfE2tpi7Pv63LJZtPh          0.000372   9.0     0.222
#
#    loudness  mode               name  popularity release_date  speechiness  \
# 0   -13.441   1.0  Shout to the Lord        47.0         2000       0.0290
# 1    -9.841   0.0           Miss You        51.0   2000-12-12       0.0407
#
#      tempo  valence    year
# 0  136.123   0.0396  2000.0
# 1  117.382   0.8030  2000.0

# %%
# Visualize the distribution of acousticness with a histogram
sns.histplot(data = spotify_2000_2020, x = 'acousticness', binwidth=0.01, alpha = 0.5, color="blue")
plt.show()

# %%
sns.histplot(data = spotify_2000_2020.sample(n=100), x = 'acousticness', binwidth=0.01, color="red", alpha = 0.5)
# Out:
# <Axes: xlabel='acousticness', ylabel='Count'>

# %% [markdown]
# <h4>Are these findings generalizable?</h4>
#
# >Let's look at another sample to see if it is representative of the population. This time, you'll look at the `duration_minutes` column of the Spotify dataset, which contains the length of the song in minutes.
#
# >`spotify_population` and `spotify_mysterious_sample2` are available; `pandas`, `matplotlib.pyplot`, and `numpy` are loaded using their standard aliases.

# %%
# Visualize the distribution of duration_minutes as a histogram
spotify_2000_2020['duration_minutes'].hist(bins=np.arange(0,15.5,0.5))
plt.show()

# %%
# Update the histogram to use spotify_mysterious_sample2
spotify_2000_2020['duration_minutes'].hist(bins=np.arange(0, 15.5, 0.5), color = 'r')
plt.xlabel("Duration(m)")
plt.ylabel("Count")

plt.show()

# %%
np.random.seed(123)
spotify_mysterious_sample2 = spotify_2000_2020.sample(n = 50)
spotify_mysterious_sample2['duration_minutes'].hist(bins=np.arange(0, 15.5, 0.5))
plt.xlabel("Duration(m)")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# <h4 style = "color: 'yellow';">Pseudo-random number generation</h4>

# %%
np.random.seed(2000229)
randoms = np.random.beta(a=2, b=2, size=5000)
randoms
# Out:
# array([0.65834391, 0.3182844 , 0.90630976, ..., 0.67270976, 0.18189324,
#        0.09213172])

# %%
sns.histplot(data=pd.DataFrame({'ran':randoms}), x = 'ran', bins=np.arange(0,1,0.05))
# Out:
# <Axes: xlabel='ran', ylabel='Count'>

# %% [markdown]
# <h4>Generating random numbers</h4>
#
# >You've used `.sample()` to generate pseudo-random numbers from a set of values in a DataFrame. A related task is to generate random numbers that follow a statistical distribution, like the uniform distribution or the normal distribution.
#
# >Each random number generation function has distribution-specific arguments and an argument for specifying the number of random numbers to generate.
#
# >`matplotlib.pyplot` is loaded as `plt`, and `numpy` is loaded as `np`

# %%
# Generate random numbers from a Uniform(-3, 3)
uniforms = np.random.uniform(-3,3,5000)

# Print uniforms
uniforms
# Out:
# array([-2.76523625, -0.69749832, -2.22858606, ...,  1.75528884,
#         0.28295298, -0.39123097])

# %%
plt.hist(x = uniforms, bins = np.arange(-3,3,0.25))
# Out:
# (array([191., 229., 228., 219., 251., 215., 189., 176., 199., 230., 191.,
#         198., 225., 172., 222., 206., 204., 217., 200., 207., 185., 232.,
#         214.]),
#  array([-3.  , -2.75, -2.5 , -2.25, -2.  , -1.75, -1.5 , -1.25, -1.  ,
#         -0.75, -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,
#          1.5 ,  1.75,  2.  ,  2.25,  2.5 ,  2.75]),
#  <BarContainer object of 23 artists>)

# %%
# Generate random numbers from a Normal(5, 2)
normals = np.random.normal(loc=5, scale=2, size=5000)

# Print normals
normals
# Out:
# array([ 4.44027495,  7.90545751, -0.45399745, ...,  5.01217697,
#         7.79760796,  5.7951675 ])

# %% [markdown]
# <img src="file:///Users/nguyentam/Desktop/Screenshot%202023-11-10%20at%2001.15.25.png">

# %%
plt.hist(x = normals, bins = np.arange(-3,3,0.25))
# Out:
# (array([  0.,   0.,   1.,   0.,   1.,   2.,   1.,   2.,   0.,   6.,   6.,
#           7.,  12.,  13.,  16.,  32.,  32.,  51.,  65.,  82., 103., 112.,
#         123.]),
#  array([-3.  , -2.75, -2.5 , -2.25, -2.  , -1.75, -1.5 , -1.25, -1.  ,
#         -0.75, -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,
#          1.5 ,  1.75,  2.  ,  2.25,  2.5 ,  2.75]),
#  <BarContainer object of 23 artists>)

# %% [markdown]
# <h4>Simple random and systematic sampling</h4>

# %% [markdown]
# <b>Simple random sampling with pandas</b>

# %%
coffee_ratings_full.sample(n=5, random_state=19000113)
# Out:
#      total_cup_points  species                           owner  \
# 437             83.25  Arabica  exportadora de cafe condor s.a
# 285             83.83  Arabica                 ipanema coffees
# 784             82.08  Arabica                   cafe politico
# 648             82.58  Arabica  exportadora de cafe condor s.a
# 155             84.58  Arabica  exportadora de cafe condor s.a
#
#     country_of_origin          farm_name lot_number  \
# 437          Colombia               None       None
# 285            Brazil  fazenda rio verde       None
# 784          Colombia               None       None
# 648          Colombia               None       None
# 155          Colombia            various       None
#
#                                       mill     ico_number  \
# 437  trilladora bonanza - armenia quindioa      3-68-0205
# 285                        ipanema coffees  002/4177/0121
# 784                                   None      3-59-1656
# ...

# %% [markdown]
# <b>Systematic sampling</b>

# %%
sample_size = 5
pop_size = len(coffee_ratings_full)
print(pop_size)
# Out:
# 1338

# %%
interval = pop_size // sample_size
print(interval)
# Out:
# 267

# %%
coffee_ratings_full.iloc[::interval]
# Out:
#       total_cup_points  species                             owner  \
# 0                90.58  Arabica                         metad plc
# 267              83.92  Arabica  federacion nacional de cafeteros
# 534              82.92  Arabica      consejo salvadoreño del café
# 801              82.00  Arabica            lin, che-hao krude 林哲豪
# 1068             80.50  Arabica          cqi taiwan icp cqi台灣合作夥伴
# 1335             77.17  Robusta                       james moore
#
#      country_of_origin                                     farm_name  \
# 0             Ethiopia                                     metad plc
# 267           Colombia                                          None
# 534        El Salvador                                santa josefita
# 801             Taiwan  you siang coffee farmtainan, taiwan 台灣台南優香咖啡
# 1068            Taiwan                                           王秋金
# 1335     United States                               fazenda cazengo
#
# ...

# %% [markdown]
# <b>The trouble with systematic sampling</b>

# %%
coffee_ratings_with_id = coffee_ratings_full.reset_index()
print(coffee_ratings_with_id)
coffee_ratings_with_id.plot(x="index", y="aftertaste", kind="scatter")
plt.show()
# Out:
#       index  total_cup_points  species                     owner  \
# 0         0             90.58  Arabica                 metad plc
# 1         1             89.92  Arabica                 metad plc
# 2         2             89.75  Arabica  grounds for health admin
# 3         3             89.00  Arabica       yidnekachew dabessa
# 4         4             88.83  Arabica                 metad plc
# ...     ...               ...      ...                       ...
# 1333   1333             78.75  Robusta               luis robles
# 1334   1334             78.08  Robusta               luis robles
# 1335   1335             77.17  Robusta               james moore
# 1336   1336             75.08  Robusta             cafe politico
# 1337   1337             73.75  Robusta             cafe politico
#
#      country_of_origin                                 farm_name lot_number  \
# 0             Ethiopia                                 metad plc       None
# ...

# %% [markdown]
# >Systematic sampling is only safe if we don't see a pattern in this scatter plot

# %%
shuffled = coffee_ratings_full.sample(frac=1)
shuffled = shuffled.reset_index(drop=True).reset_index()
shuffled.plot(x="index", y="aftertaste", kind="scatter")
plt.show()

# %% [markdown]
#  This is great, but note that once we've shuffled the rows, systematic sampling is essentially the same as simple random sampling.

# %% [markdown]
# <h4>Simple random sampling</h4>
#
# >The simplest method of sampling a population is the one you've seen already. It is known as simple random sampling (sometimes abbreviated to "SRS"), and involves picking rows at random, one at a time, where each row has the same chance of being picked as any other.
#
# >In this chapter, you'll apply sampling methods to a synthetic (fictional) employee attrition dataset from IBM, where "attrition" in this context means leaving the company.
#
# >`attrition` is *available*; `pandas` as pd is *loaded*.

# %%
# Sample 70 rows using simple random sampling and set the seed
attrition_samp = attrition.sample(n = 70, random_state=18900217)

# Print the sample
attrition_samp
# Out:
#       Age  Attrition     BusinessTravel  DailyRate            Department  \
# 1134   35        0.0      Travel_Rarely        583  Research_Development
# 1150   52        0.0         Non-Travel        585                 Sales
# 531    33        0.0      Travel_Rarely        931  Research_Development
# 395    31        0.0      Travel_Rarely       1332  Research_Development
# 392    29        0.0      Travel_Rarely        942  Research_Development
# ...   ...        ...                ...        ...                   ...
# 361    27        0.0  Travel_Frequently       1410                 Sales
# 1180   36        0.0      Travel_Rarely        530                 Sales
# 230    26        0.0      Travel_Rarely       1443                 Sales
# 211    29        0.0  Travel_Frequently        410  Research_Development
# 890    30        0.0  Travel_Frequently       1312  Research_Development
#
#       DistanceFromHome      Education    EducationField  \
# ...

# %% [markdown]
# <h4>Systematic sampling</h4>
#
# >One sampling method that avoids randomness is called systematic sampling. Here, you pick rows from the population at regular intervals.
#
# >For example, if the population dataset had one thousand rows, and you wanted a sample size of five, you could pick rows `0, 200, 400, 600, and 800`.
#
# >`attrition` is available; `pandas` has been pre-loaded as pd.

# %%
# Set the sample size to 70
sample_size = 70

# Calculate the population size from attrition
pop_size = len(attrition)

# Calculate the interval
interval = pop_size//sample_size
interval
# Out:
# 21

# %% [markdown]
# >Systematically sample `attrition` to get the rows of the population at each interval, *starting at 0*; assign the rows to attrition_sys_samp.

# %%
# Systematically sample 70 rows
attrition_sys_samp = attrition.iloc[::interval]

# Print the sample
attrition_sys_samp
# Out:
#       Age  Attrition BusinessTravel  DailyRate            Department  \
# 0      21        0.0  Travel_Rarely        391  Research_Development
# 21     19        0.0  Travel_Rarely       1181  Research_Development
# 42     45        0.0  Travel_Rarely        252  Research_Development
# 63     23        0.0  Travel_Rarely        373  Research_Development
# 84     30        1.0  Travel_Rarely        945                 Sales
# ...   ...        ...            ...        ...                   ...
# 1365   48        0.0  Travel_Rarely        715  Research_Development
# 1386   48        0.0  Travel_Rarely       1355  Research_Development
# 1407   50        0.0  Travel_Rarely        989  Research_Development
# 1428   50        0.0     Non-Travel        881  Research_Development
# 1449   52        0.0  Travel_Rarely        699  Research_Development
#
#       DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# ...

# %% [markdown]
# <h4>Is systematic sampling OK?</h4>
#
# >Systematic sampling has a problem: if the data has been sorted, or there is some sort of pattern or meaning behind the row order, then the resulting sample may not be representative of the whole population. The problem can be solved by shuffling the rows, but then systematic sampling is equivalent to simple random sampling.
#
# >Here you'll look at how to determine whether or not there is a problem.
#
# >`attrition` is available; `pandas` is loaded as `pd`, and `matplotlib.pyplot` as `plt`.

# %% [markdown]
# Add an index column to `attrition`, assigning the result to `attrition_pop_id`.
# Create a scatter plot of `YearsAtCompany` versus `index` for `attrition_pop_id` using pandas `.plot()`.

# %%
# Add an index column to attrition
attrition_pop_id = attrition.reset_index()

# Plot YearsAtCompany vs. index for attrition_pop_id
attrition_pop_id.plot(x = 'index', y = 'YearsAtCompany', kind = 'scatter')
plt.show()

# %% [markdown]
# >Randomly shuffle the rows of `attrition`.
#
# >Reset the row indexes, and add an index column to `attrition`.
#
# >Repeat the scatter plot of `YearsAtCompany` versus `index`, this time using `attrition_shuffled`.

# %%
# Shuffle the rows of attrition
attrition_shuffled = attrition.sample(frac=1)

# Reset the row indexes and create an index column
attrition_shuffled = attrition_shuffled.reset_index(drop=True).reset_index()
# Plot YearsAtCompany vs. index for attrition_shuffled
attrition_shuffled.plot(x = 'index', y = 'YearsAtCompany', kind = 'scatter')
plt.show()

# %% [markdown]
# <h4>Stratified and weighted random sampling</h4>

# %% [markdown]
# <h4>Coffees by country</h4>

# %%
top_counts = coffee_ratings_full['country_of_origin'].value_counts()
top_counts.head(6)
# Out:
# country_of_origin
# Mexico                    236
# Colombia                  183
# Guatemala                 181
# Brazil                    132
# Taiwan                     75
# United States (Hawaii)     73
# Name: count, dtype: int64

# %%
top_counted_countries = ['Mexico',
                        'Colombia',
                        'Guatemala',
                        'Brazil',
                        'Taiwan',
                        'United States (Hawaii)']
top_counted_countries
